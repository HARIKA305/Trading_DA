# %% [markdown]
# #**TRADING DATA ANLYSIS**
#
# **BATCH - 6**
#
# **BATCH-MEMBERS :-**
#
# * DUVVA SURESH CSINP318 **(T L)**
#
# * RAMBA JAYA HARIKA CSINP327
#
# * KADIYAM UMAMAHESWARI CSINP339
#
# * DOREDLA SARANYA CSINP342
#
# * POLISETTY AMALA MARY CSINP346
#
# * PRAMODH MADICHARLA CSINP353
#
# * SINDHU CHINTA CSINP360

# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ## **RAW DATA**

# %%
date=['12-02-2022','12-02-2022','12-02-2022','14-02-2022','14-02-2022','14-02-2022','14-02-2022','15-02-2022','05-03-2022','05-03-2022',
      '06-03-2022','06-03-2022','07-03-2022','08-03-2022','08-03-2022','09-03-2022','10-03-2022','11-03-2022','12-03-2022','13-03-2022',
      '16-03-2022','17-03-2022','18-03-2022','18-03-2022','19-03-2022','20-03-2022','22-03-2022','23-03-2022','24-03-2022','25-03-2022',
      '26-03-2022','27-03-2022','05-04-2022','05-04-2022','06-04-2022','07-04-2022','08-04-2022','09-04-2022','11-04-2022','12-04-2022',
      '13-04-2022','14-04-2022','15-04-2022','17-04-2022','18-04-2022','18-04-2022','19-04-2022','20-04-2022','22-04-2022','22-04-2022']



script_Id=['INE5A0001','INE5A0002','INE5A0003','INE5A0004','INE5A0005','INE5A0006','INE5A0007','INE5A0008','INE5A0009','INE5A0010',
           'INE6B003','INE5BA01','INE5BA03','INE5VA008','INE5GA005','INEV5A006','INE5GB007','INE6YA008','INE5HA009','INE5DA010',
           'INE20RGA1','INE201H5A','INE4RA003','INETA56002','INE45G607','INE0HA006','INE0075A','INE5AHO1001','INETG5A008','INE5A0010',
           'INE5A001D','INE5D002E','INE5A003F','INE5A004G','INE56005H','INE5A006I','INE7G00J','INE0ER08K','INE0UA09L','INE06O10M',
           'INEYA001','INE5QOO2','INE5Q7600','INE5A00G6','INE6A007R','INE5AOO5D','INE5A009J','INERF00UH','INE9K005','INE6AKO10']



sector=['oil corporation','oil corporation','oil corporation','power grid corporation','metals','coco cola','coco cola','coco cola','power grid corporation','power grid corporation',
        'power grid corporation','electronics','electronics','electronics','electronics','electronics','electronics','electronics','electronics','electronics',
        'telecom','telecom','telecom','telecom','telecom','telecom','financial corporation','financial corporation','financial corporation','financial corporation',
        'financial corporation','financial corporation','financial corporation','financial corporation','financial corporation','financial corporation','financial corporation','financial corporation','power grid corporation','it sector',
        'vechile','ferrous','it sector','financial','financial','building material','medical','thermal','vechile','building material']



exchange=['NSE','NSE','BSE','NSE','NSE','NSE','NSE','NSE','NSE','BSE',
          'BSE','NSE','NSE','NSE','BSE','BSE','BSE','BSE','NSE','NSE',
          'BSE','BSE','BSE','BSE','NSE','NSE','NSE','NSE','NSE','NSE',
          'BSE','BSE','BSE','BSE','BSE','NSE','NSE','NSE','NSE','NSE',
          'NSE','NSE','NSE','NSE','NSE','BSE','BSE','NSE','BSE','NSE']



Type=['buy','sell','buy','buy','buy','buy','buy,','buy','buy','sell',
      'sell','sell','sell','sell','buy','sell','buy','buy','buy','sell',
      'sell','sell','sell','sell','sell','buy','buy','sell','sell','sell',
      'buy','buy','buy','sell','sell','buy','buy','sell','buy','buy','sell',
      'buy','buy','buy','sell','sell','sell','sell','sell','buy']



Quantity=[20,np.nan,30,np.nan,30,200,40,36,67,80,
          100,56,90,np.nan,100,67,60,98,78,65,
          100,67,90,np.nan,87,90,200,87,np.nan,np.nan,
          200,125,175,20,np.nan,np.nan,56,89,76,76,
          50,76,90,80,100,30,np.nan,np.nan,np.nan,np.nan]



brokername=['(UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED','(UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED','(UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED','(UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED','(UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED','ANGEL ONE LIMITED',
'ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','ANGEL ONE LIMITED','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD',
'KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD','KOTAK SECURITIES LTD',
'5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','5PAISA CAPITAL LIMITED','PAYTM MONEY LTD','PAYTM MONEY LTD','PAYTM MONEY LTD',
'PAYTM MONEY LTD','PAYTM MONEY LTD','PAYTM MONEY LTD','PAYTM MONEY LTD','PAYTM MONEY LTD','PAYTM MONEY LTD','PAYTM MONEY LTD']




brokerage_fee=[0.45,np.nan,np.nan,np.nan,0.45,0.34,0.45,0.36,0.78,0.76,
               0.63,0.69,0.74,np.nan,0.23,0.45,0.56,1.03,0.67,0.45,
               0.56,1.34,1.03,np.nan,0.56,0.65,0.65,0.46,0.63,0.72,
               1.43,1.45,1.45,np.nan,0.56,np.nan,0.76,0.56,0.53,1.54,
               1.45,1.64,0.65,np.nan,0.42,0.43,np.nan,np.nan,np.nan,0.87]



gst=[0.23,3.45,2.34,np.nan,1.23,1.34,1.46,1.54,1.45,4.67,
     4.56,np.nan,4.67,5.78,np.nan,3.56,3.45,6.45,3.45,8.99,
     6.67,6.69,5.87,2.45,5.23,np.nan,7.67,8.56,np.nan,np.nan,
     7.46,np.nan,np.nan,np.nan,4.56,6.96,4.76,3.54,5.76,np.nan,
     6.76,9.76,4.65,8.87,6.87,np.nan,np.nan,np.nan,np.nan,5.47]



stt=[0.67,0.78,np.nan,np.nan,0.87,0.78,0.78,0.67,0.56,0.56,
     0.99,np.nan,np.nan,np.nan,0.68,0.65,0.67,0.56,0.76,0.75,
     np.nan,np.nan,np.nan,0.87,0.78,0.77,0.87,np.nan,np.nan,np.nan,
     np.nan,0.78,0.87,0.76,0.76,0.76,0.76,0.76,np.nan,np.nan,
     np.nan,0.78,0.78,0.58,0.78,0.76,0.87,0.89,0.88,np.nan]



sebi=[0.89,0.88,np.nan,np.nan,np.nan,np.nan,0.78,0.78,0.89,0.69,
      np.nan,np.nan,np.nan,np.nan,np.nan,0.87,0.87,0.87,0.76,0.56,
      np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,0.78,0.78,0.67,0.78,
      0.67,0.67,0.76,0.87,0.87,np.nan,np.nan,np.nan,np.nan,np.nan,
      0.89,0.67,0.67,np.nan,np.nan,0.78,0.78,0.66,np.nan,np.nan]



stampduty=[0.56,0.67,0.67,0.67,0.56,0.67,np.nan,np.nan,np.nan,np.nan,
           0.67,0.56,0.67,0.67,0.76,0.67,0.78,np.nan,np.nan,0.67,
           0.67,np.nan,np.nan,0.78,0.67,0.67,0.48,0.67,np.nan,np.nan,
           0.67,0.56,0.56,0.67,0.57,0.78,np.nan,np.nan,np.nan,0.78,
           0.56,0.56,np.nan,np.nan,np.nan,0.78,0.67,0.68,0.67,np.nan]
orderno=['100589001','011322675','000765442','0874544564','0774544224','0653434556','8389292292','883992922','882828282','085363721',
         '7478329292','383292221','6474839221','7456372004','73728292','2728229292','72828292','737388293','45644567','654457545',
         '45543755456','564456454','564544545','45456564564','573454747','74547543754','7647646454','732327327','372657826','34234623734',
         '345327437','32236243','347326732','2363262784','325322364','343243232','36547655','3534654767','353456547','43654765658',
         '534654767','433253464','454567568','44565457','6474324','46454747','465654727','564764742','265475727','645767858']
trade_name =['indian oil','hpcl','bharat petroleum','ntpc ','vadanta ltd','coco cola','thumbsup','limca','apedcl','ap janko',
              'ap transco','samsung','lenovo','vivo','redmi','iphone','oppo','realme','nokia','lava',
              'airtel','idea','bsnl','vodafone','tatadocomo','jio','sbi bank','hdfc bank','canara bank','icici bank',
              'corporation bank','union bank','andhra bank','indian bank','bank of borada',' axis bank','central bank','reserve bank','ntpc ltd','infosys ltd',
              'tata motors','tata steel ltd','wipro ltc','bajaj auto ltd','bajaj finance ltd','asian paints ltd',' apollo hospital ltd','coal india ltd','hero motors ltd','shree cement ltd']


buyprice=[290,450,560.76,460.78,901.90,np.nan,np.nan,np.nan,np.nan,567.90,
          506.90,np.nan,np.nan,705.09,504.76,np.nan,np.nan,np.nan,546.76,np.nan,
          np.nan,np.nan,689.09,np.nan,np.nan,np.nan,np.nan,785.67,456.87,674.67,
          np.nan,np.nan,567.67,789.79,906.78,np.nan,np.nan,np.nan,np.nan,np.nan,
          780.67,806.68,679.95,609.78,907.78,789.07,789.90,np.nan,865.90,678.89]


sellprice=[np.nan,np.nan,np.nan,907.89,679.90,856.78,np.nan,np.nan,789.90,785.78,
           675.78,654.76,786.68,875.67,876.89,np.nan,np.nan,np.nan,643.67,np.nan,
           np.nan,678.46,657.76,np.nan,np.nan,np.nan,764.68,895.57,np.nan,np.nan,
           765.76,675.57,765.67,657.57,np.nan,np.nan,np.nan,657.57,np.nan,674.76,
           np.nan,np.nan,769.68,654.76,675.90,768.78,np.nan,np.nan,890.67,np.nan]



dayhigh=[359.67,764.7,np.nan,np.nan,np.nan,734.67,673.56,764.67,785.67,786.67,
         np.nan,np.nan,np.nan,np.nan,657.57,567.67,675.57,678.78,675.56,678.67,
         np.nan,np.nan,567.57,679.68,675.67,np.nan,np.nan,np.nan,675.55,np.nan,
         675.56,456.87,675.56,576.68,567.45,345.56,np.nan,np.nan,np.nan,np.nan,
         890.67,576.67,678.67,789.67,np.nan,np.nan,np.nan,678.57,np.nan,np.nan]



daylow=[345.56,564.46,654.67,657.57,675.57,654.67,345.56,np.nan,np.nan,np.nan,
        234.45,456.56,564.67,np.nan,np.nan,np.nan,np.nan,345.56,345.78,342.45,
        np.nan,np.nan,345.56,456.48,342.77,345.67,675.56,463.56,564.44,345.67,
        np.nan,np.nan,np.nan,np.nan,345.67,234.45,345.67,np.nan,564.56,np.nan,
        np.nan,np.nan,np.nan,345.67,453.56,235.56,456.67,234.89,np.nan,np.nan]



openprice=[230,240,np.nan,253.66,np.nan,140.66,np.nan,145.69,146.69,150.64,
           234.78,243.69,244.96,np.nan,343.63,np.nan,345.67,567.89,345.64,340.75,
           np.nan,235.77,238.99,255.67,np.nan,258.96,234.56,np.nan,534.78,345.89,
           np.nan,np.nan,456.67,345.78,np.nan,568.95,348.69,678.76,258.86,289.80,
           350.67,450.69,567.78,np.nan,678.78,654.66,549.78,674.66,675.87,540.80]



personname=['chandra','suresh','sirisha','harika','saranya','promodh','mary','amala','sindu','ramba',
            'jaya','urvasi','sunny','samantha','samatha','durga','prasad','ramana','rupa','bhavani',
            'vishwa','satya','nandini','ram','nithin','charan','rajnikanth','tarak','kalyan','pawan',
            'praveen','uma','maheswari','mahesh','eswari','siva','sekhar','naga devi','prasad','janani',
            'blake blossam','cherry','jhonny sins','mia malkova','mia khalifa','tony','shanker','gowtham','bala krishna','gopi']



panno=['APO5EE9078','APO5O6GGG5A','APO5OOH6345','APO590OO7T8','APO5UY67001','APO5LO9087','APO590O007','APO590887','APO58900E4','APO59IK887',
       'APO5RA005','APO57A003','AP05TA22005','APO5GR55A9','APO5900Y6','APO5ERFG3','APO59IKK8','APO5UA550','APO5RA223','APO567RRA2',
       'APORGH5A009','PB065A007','KAO6HA007','KO98KA7001','KOT68JA1','HAO90078','AO06HH62','ASO7BN009','HN560089','JK007OOK8',
       'AP0B6HH5AG9','GU6JNNA90','TY6678005','RAOO67H56','GH6706GU1','RT67008GA01','HJ7AFG678','HU89700GA1','HU7T5601','KO87OOUT1',
       'TYOP9065','HJ6755FA','HJUU76FA5','HJY667GA','GH658JK1','HJU67A20','OG80OOP001','UJ7765RA1','KOTOO086','GH6Y0067']



uccno=['2000155674','2345518900','0999670054','676466894','6756545501','870014567','566780743','7863780045','870018956','780853434',
       '67007000012','0977667001','67557600123','6743500123','5637720','78690489','097878001','674562980','09887813001','870889010',
       '67587098801','78600457643','5670056A001','653400123','6755300234','765300125','67553008234','8766OO2001','89776001001','08601123090',
       '78600675','8755462201','675530017','2000155674','6788456','9077564','764400352','897723456','907754267','9077536',
       '67554830','65448342','786645201','897754230','67553001','670045632','7855462001','89005631','78994561','78996531']

# %% [markdown]
# ## **data framing**

# %%
data={'DATE':date,
    'SCRIPT_ID':script_Id,
    'SECTOR':sector,
    'EXCHANGE':exchange,
    'QUANTITY':Quantity,
    'TYPE':Type,
    'BROKER_NAME':brokername,
    'ORDERNO':orderno,
    'TRADE_NAME':trade_name,
    'PERSON_NAME':personname,
    'PAN_NO':panno,
    'UCC_NO':uccno}

# %%
dataset=pd.DataFrame(data,columns=['DATE','SCRIPT_ID','SECTOR','EXCHANGE','QUANTITY','TYPE','BROKER_NAME','ORDERNO','TRADE_NAME','PERSON_NAME','PAN_NO','UCC_NO'])
dataset.head()#5
# Out:
#          DATE  SCRIPT_ID                  SECTOR EXCHANGE  QUANTITY  TYPE  \
# 0  12-02-2022  INE5A0001         oil corporation      NSE      20.0   buy
# 1  12-02-2022  INE5A0002         oil corporation      NSE       NaN  sell
# 2  12-02-2022  INE5A0003         oil corporation      BSE      30.0   buy
# 3  14-02-2022  INE5A0004  power grid corporation      NSE       NaN   buy
# 4  14-02-2022  INE5A0005                  metals      NSE      30.0   buy
#
#                                       BROKER_NAME     ORDERNO  \
# 0  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   100589001
# 1  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   011322675
# 2  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   000765442
# 3  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED  0874544564
# 4  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED  0774544224
#
#          TRADE_NAME PERSON_NAME       PAN_NO      UCC_NO
# 0        indian oil     chandra   APO5EE9078  2000155674
# 1              hpcl      suresh  APO5O6GGG5A  2345518900
# 2  bharat petroleum     sirisha  APO5OOH6345  0999670054
# 3             ntpc       harika  APO590OO7T8   676466894
# 4       vadanta ltd     saranya  APO5UY67001  6756545501

# %%
dataset.tail()#5
# Out:
#           DATE  SCRIPT_ID             SECTOR EXCHANGE  QUANTITY  TYPE  \
# 45  18-04-2022  INE5AOO5D  building material      BSE      30.0  sell
# 46  19-04-2022  INE5A009J            medical      BSE       NaN  sell
# 47  20-04-2022  INERF00UH            thermal      NSE       NaN  sell
# 48  22-04-2022   INE9K005            vechile      BSE       NaN  sell
# 49  22-04-2022  INE6AKO10  building material      NSE       NaN   buy
#
#         BROKER_NAME    ORDERNO            TRADE_NAME   PERSON_NAME  \
# 45  PAYTM MONEY LTD   46454747      asian paints ltd          tony
# 46  PAYTM MONEY LTD  465654727   apollo hospital ltd       shanker
# 47  PAYTM MONEY LTD  564764742        coal india ltd       gowtham
# 48  PAYTM MONEY LTD  265475727       hero motors ltd  bala krishna
# 49  PAYTM MONEY LTD  645767858      shree cement ltd          gopi
#
#         PAN_NO      UCC_NO
# 45    HJU67A20   670045632
# 46  OG80OOP001  7855462001
# 47   UJ7765RA1    89005631
# 48    KOTOO086    78994561
# 49    GH6Y0067    78996531

# %%
dataset.dtypes
# Out:
# DATE            object
# SCRIPT_ID       object
# SECTOR          object
# EXCHANGE        object
# QUANTITY       float64
# TYPE            object
# BROKER_NAME     object
# ORDERNO         object
# TRADE_NAME      object
# PERSON_NAME     object
# PAN_NO          object
# UCC_NO          object
# dtype: object

# %%
empty=[np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
       np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
       np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
       np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
       np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]

# %%
Data={
    'OPENPRICE':openprice,
    'DAYHIGH':dayhigh,
    'DAYLOW':daylow,
    'BUYPRICE':buyprice,
    'SELLPRICE':sellprice,
    'GOVERNAMENT_SERVICE_TAX(GST)':gst,
    'SECURITIES_TRANSCATION_TAX(STT)':stt,
    'SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)':sebi,
    'STAMPDUTY':stampduty,
    'BROKERAGE_FEE':brokerage_fee,
    'empty':empty
}

# %%
dataset1=pd.DataFrame(Data,columns=['OPENPRICE','DAYHIGH','DAYLOW','BUYPRICE','SELLPRICE','GOVERNAMENT_SERVICE_TAX(GST)','SECURITIES_TRANSCATION_TAX(STT)','SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)','STAMPDUTY','BROKERAGE_FEE','empty'])
dataset1.head()
# Out:
#    OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 0     230.00   359.67  345.56    290.00        NaN
# 1     240.00   764.70  564.46    450.00        NaN
# 2        NaN      NaN  654.67    560.76        NaN
# 3     253.66      NaN  657.57    460.78     907.89
# 4        NaN      NaN  675.57    901.90     679.90
#
#    GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 0                          0.23                             0.67
# 1                          3.45                             0.78
# 2                          2.34                              NaN
# 3                           NaN                              NaN
# 4                          1.23                             0.87
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 0                                          0.89       0.56           0.45
# 1                                          0.88       0.67            NaN
# 2                                           NaN       0.67            NaN
# 3                                           NaN       0.67            NaN
# 4                                           NaN       0.56           0.45
#
#    empty
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
dataset1.tail()
# Out:
#     OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 45     654.66      NaN  235.56    789.07     768.78
# 46     549.78      NaN  456.67    789.90        NaN
# 47     674.66   678.57  234.89       NaN        NaN
# 48     675.87      NaN     NaN    865.90     890.67
# 49     540.80      NaN     NaN    678.89        NaN
#
#     GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 45                           NaN                             0.76
# 46                           NaN                             0.87
# 47                           NaN                             0.89
# 48                           NaN                             0.88
# 49                          5.47                              NaN
#
#     SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 45                                          0.78       0.78           0.43
# 46                                          0.78       0.67            NaN
# 47                                          0.66       0.68            NaN
# 48                                           NaN       0.67            NaN
# 49                                           NaN        NaN           0.87
#
#     empty
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN

# %%
dataset.columns
# Out:
# Index(['DATE', 'SCRIPT_ID', 'SECTOR', 'EXCHANGE', 'QUANTITY', 'TYPE',
#        'BROKER_NAME', 'ORDERNO', 'TRADE_NAME', 'PERSON_NAME', 'PAN_NO',
#        'UCC_NO'],
#       dtype='object')

# %%
dataset1.columns
# Out:
# Index(['OPENPRICE', 'DAYHIGH', 'DAYLOW', 'BUYPRICE', 'SELLPRICE',
#        'GOVERNAMENT_SERVICE_TAX(GST)', 'SECURITIES_TRANSCATION_TAX(STT)',
#        'SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)', 'STAMPDUTY',
#        'BROKERAGE_FEE', 'empty'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (50, 12)

# %%
dataset1.shape
# Out:
# (50, 11)

# %% [markdown]
# -------------**find the null values**-----------

# %%
dataset.isna().head()
# Out:
#     DATE  SCRIPT_ID  SECTOR  EXCHANGE  QUANTITY   TYPE  BROKER_NAME  ORDERNO  \
# 0  False      False   False     False     False  False        False    False
# 1  False      False   False     False      True  False        False    False
# 2  False      False   False     False     False  False        False    False
# 3  False      False   False     False      True  False        False    False
# 4  False      False   False     False     False  False        False    False
#
#    TRADE_NAME  PERSON_NAME  PAN_NO  UCC_NO
# 0       False        False   False   False
# 1       False        False   False   False
# 2       False        False   False   False
# 3       False        False   False   False
# 4       False        False   False   False

# %%
dataset.isna().tail()
# Out:
#      DATE  SCRIPT_ID  SECTOR  EXCHANGE  QUANTITY   TYPE  BROKER_NAME  ORDERNO  \
# 45  False      False   False     False     False  False        False    False
# 46  False      False   False     False      True  False        False    False
# 47  False      False   False     False      True  False        False    False
# 48  False      False   False     False      True  False        False    False
# 49  False      False   False     False      True  False        False    False
#
#     TRADE_NAME  PERSON_NAME  PAN_NO  UCC_NO
# 45       False        False   False   False
# 46       False        False   False   False
# 47       False        False   False   False
# 48       False        False   False   False
# 49       False        False   False   False

# %%
dataset.notnull().head()
# Out:
#    DATE  SCRIPT_ID  SECTOR  EXCHANGE  QUANTITY  TYPE  BROKER_NAME  ORDERNO  \
# 0  True       True    True      True      True  True         True     True
# 1  True       True    True      True     False  True         True     True
# 2  True       True    True      True      True  True         True     True
# 3  True       True    True      True     False  True         True     True
# 4  True       True    True      True      True  True         True     True
#
#    TRADE_NAME  PERSON_NAME  PAN_NO  UCC_NO
# 0        True         True    True    True
# 1        True         True    True    True
# 2        True         True    True    True
# 3        True         True    True    True
# 4        True         True    True    True

# %%
dataset.notnull().tail()
# Out:
#     DATE  SCRIPT_ID  SECTOR  EXCHANGE  QUANTITY  TYPE  BROKER_NAME  ORDERNO  \
# 45  True       True    True      True      True  True         True     True
# 46  True       True    True      True     False  True         True     True
# 47  True       True    True      True     False  True         True     True
# 48  True       True    True      True     False  True         True     True
# 49  True       True    True      True     False  True         True     True
#
#     TRADE_NAME  PERSON_NAME  PAN_NO  UCC_NO
# 45        True         True    True    True
# 46        True         True    True    True
# 47        True         True    True    True
# 48        True         True    True    True
# 49        True         True    True    True

# %%
dataset1.isna().head()
# Out:
#    OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 0      False    False   False     False       True
# 1      False    False   False     False       True
# 2       True     True   False     False       True
# 3      False     True   False     False      False
# 4       True     True   False     False      False
#
#    GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                             True
# 3                          True                             True
# 4                         False                            False
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 0                                         False      False          False
# 1                                         False      False           True
# 2                                          True      False           True
# 3                                          True      False           True
# 4                                          True      False          False
#
#    empty
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True

# %%
dataset1.isna().tail()
# Out:
#     OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 45      False     True   False     False      False
# 46      False     True   False     False       True
# 47      False    False   False      True       True
# 48      False     True    True     False      False
# 49      False     True    True     False       True
#
#     GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 45                          True                            False
# 46                          True                            False
# 47                          True                            False
# 48                          True                            False
# 49                         False                             True
#
#     SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 45                                         False      False          False
# 46                                         False      False           True
# 47                                         False      False           True
# 48                                          True      False           True
# 49                                          True       True          False
#
#     empty
# 45   True
# 46   True
# 47   True
# 48   True
# 49   True

# %%
dataset1.notnull().head()
# Out:
#    OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 0       True     True    True      True      False
# 1       True     True    True      True      False
# 2      False    False    True      True      False
# 3       True    False    True      True       True
# 4      False    False    True      True       True
#
#    GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 0                          True                             True
# 1                          True                             True
# 2                          True                            False
# 3                         False                            False
# 4                          True                             True
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 0                                          True       True           True
# 1                                          True       True          False
# 2                                         False       True          False
# 3                                         False       True          False
# 4                                         False       True           True
#
#    empty
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
dataset1.notnull().tail()
# Out:
#     OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 45       True    False    True      True       True
# 46       True    False    True      True      False
# 47       True     True    True     False      False
# 48       True    False   False      True       True
# 49       True    False   False      True      False
#
#     GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 45                         False                             True
# 46                         False                             True
# 47                         False                             True
# 48                         False                             True
# 49                          True                            False
#
#     SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 45                                          True       True           True
# 46                                          True       True          False
# 47                                          True       True          False
# 48                                         False       True          False
# 49                                         False      False           True
#
#     empty
# 45  False
# 46  False
# 47  False
# 48  False
# 49  False

# %%
dataset.isna().sum(),dataset.isna().sum().sum()#12
# Out:
# (DATE            0
#  SCRIPT_ID       0
#  SECTOR          0
#  EXCHANGE        0
#  QUANTITY       12
#  TYPE            0
#  BROKER_NAME     0
#  ORDERNO         0
#  TRADE_NAME      0
#  PERSON_NAME     0
#  PAN_NO          0
#  UCC_NO          0
#  dtype: int64,
#  12)

# %%
dataset.notnull().sum()
# Out:
# DATE           50
# SCRIPT_ID      50
# SECTOR         50
# EXCHANGE       50
# QUANTITY       38
# TYPE           50
# BROKER_NAME    50
# ORDERNO        50
# TRADE_NAME     50
# PERSON_NAME    50
# PAN_NO         50
# UCC_NO         50
# dtype: int64

# %%
dataset1.isna().sum()#.sum()#234
# Out:
# OPENPRICE                                       12
# DAYHIGH                                         22
# DAYLOW                                          20
# BUYPRICE                                        24
# SELLPRICE                                       24
# GOVERNAMENT_SERVICE_TAX(GST)                    14
# SECURITIES_TRANSCATION_TAX(STT)                 16
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)    24
# STAMPDUTY                                       17
# BROKERAGE_FEE                                   11
# empty                                           50
# dtype: int64

# %%
dataset1.notnull().sum()
# Out:
# OPENPRICE                                       38
# DAYHIGH                                         28
# DAYLOW                                          30
# BUYPRICE                                        26
# SELLPRICE                                       26
# GOVERNAMENT_SERVICE_TAX(GST)                    36
# SECURITIES_TRANSCATION_TAX(STT)                 34
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)    26
# STAMPDUTY                                       33
# BROKERAGE_FEE                                   39
# empty                                            0
# dtype: int64

# %% [markdown]
# -------**remove the empty null column**------------

# %%
dataset1=dataset1.drop('empty',axis=1)# Delete the empty column form 'df1' data set.
dataset1.columns
# Out:
# Index(['OPENPRICE', 'DAYHIGH', 'DAYLOW', 'BUYPRICE', 'SELLPRICE',
#        'GOVERNAMENT_SERVICE_TAX(GST)', 'SECURITIES_TRANSCATION_TAX(STT)',
#        'SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)', 'STAMPDUTY',
#        'BROKERAGE_FEE'],
#       dtype='object')

# %% [markdown]
# -------------**fill the null values**--------------

# %%
dataset['QUANTITY'].fillna(dataset['QUANTITY'].max(),inplace=True)
dataset.head()
# Out:
#          DATE  SCRIPT_ID                  SECTOR EXCHANGE  QUANTITY  TYPE  \
# 0  12-02-2022  INE5A0001         oil corporation      NSE      20.0   buy
# 1  12-02-2022  INE5A0002         oil corporation      NSE     200.0  sell
# 2  12-02-2022  INE5A0003         oil corporation      BSE      30.0   buy
# 3  14-02-2022  INE5A0004  power grid corporation      NSE     200.0   buy
# 4  14-02-2022  INE5A0005                  metals      NSE      30.0   buy
#
#                                       BROKER_NAME     ORDERNO  \
# 0  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   100589001
# 1  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   011322675
# 2  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   000765442
# 3  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED  0874544564
# 4  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED  0774544224
#
#          TRADE_NAME PERSON_NAME       PAN_NO      UCC_NO
# 0        indian oil     chandra   APO5EE9078  2000155674
# 1              hpcl      suresh  APO5O6GGG5A  2345518900
# 2  bharat petroleum     sirisha  APO5OOH6345  0999670054
# 3             ntpc       harika  APO590OO7T8   676466894
# 4       vadanta ltd     saranya  APO5UY67001  6756545501

# %%
dataset.isna().sum()
# Out:
# DATE           0
# SCRIPT_ID      0
# SECTOR         0
# EXCHANGE       0
# QUANTITY       0
# TYPE           0
# BROKER_NAME    0
# ORDERNO        0
# TRADE_NAME     0
# PERSON_NAME    0
# PAN_NO         0
# UCC_NO         0
# dtype: int64

# %%
dataset1['OPENPRICE'].fillna(dataset1['OPENPRICE'].min(),inplace=True)
dataset1['DAYHIGH'].fillna(dataset1['DAYHIGH'].max(),inplace=True)
dataset1['DAYLOW'].fillna(dataset1['DAYLOW'].min(),inplace=True)
dataset1['BUYPRICE'].fillna(dataset1['BUYPRICE'].max(),inplace=True)
dataset1['SELLPRICE'].fillna(dataset1['SELLPRICE'].max(),inplace=True)
dataset1['GOVERNAMENT_SERVICE_TAX(GST)'].fillna(dataset1['GOVERNAMENT_SERVICE_TAX(GST)'].max(),inplace=True)
dataset1['SECURITIES_TRANSCATION_TAX(STT)'].fillna(dataset1['SECURITIES_TRANSCATION_TAX(STT)'].min(),inplace=True)
dataset1['SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)'].fillna(dataset1['SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)'].mean(),inplace=True)
dataset1['STAMPDUTY'].fillna(dataset1['STAMPDUTY'].min(),inplace=True)
dataset1['BROKERAGE_FEE'].fillna(dataset1['BROKERAGE_FEE'].mean(),inplace=True)
dataset1.head()
# Out:
#    OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 0     230.00   359.67  345.56    290.00     907.89
# 1     240.00   764.70  564.46    450.00     907.89
# 2     140.66   890.67  654.67    560.76     907.89
# 3     253.66   890.67  657.57    460.78     907.89
# 4     140.66   890.67  675.57    901.90     679.90
#
#    GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 0                          0.23                             0.67
# 1                          3.45                             0.78
# 2                          2.34                             0.56
# 3                          9.76                             0.56
# 4                          1.23                             0.87
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE
# 0                                      0.890000       0.56       0.450000
# 1                                      0.880000       0.67       0.753333
# 2                                      0.774615       0.67       0.753333
# 3                                      0.774615       0.67       0.753333
# 4                                      0.774615       0.56       0.450000

# %%
dataset1.isna().sum()
# Out:
# OPENPRICE                                       0
# DAYHIGH                                         0
# DAYLOW                                          0
# BUYPRICE                                        0
# SELLPRICE                                       0
# GOVERNAMENT_SERVICE_TAX(GST)                    0
# SECURITIES_TRANSCATION_TAX(STT)                 0
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)    0
# STAMPDUTY                                       0
# BROKERAGE_FEE                                   0
# dtype: int64

# %%
dataset1['total_buy_price']=dataset1.BUYPRICE*dataset.QUANTITY
dataset1['total_sell_price']=dataset1.SELLPRICE*dataset.QUANTITY
dataset1['sum_of_transation_taxes/quantity']=dataset1['GOVERNAMENT_SERVICE_TAX(GST)']+dataset1['SECURITIES_TRANSCATION_TAX(STT)']+dataset1['SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)']+dataset1['STAMPDUTY']+dataset1['BROKERAGE_FEE']
dataset1['total_transcation_taxes']=dataset['QUANTITY']*dataset1['sum_of_transation_taxes/quantity']
dataset1.head()
# Out:
#    OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 0     230.00   359.67  345.56    290.00     907.89
# 1     240.00   764.70  564.46    450.00     907.89
# 2     140.66   890.67  654.67    560.76     907.89
# 3     253.66   890.67  657.57    460.78     907.89
# 4     140.66   890.67  675.57    901.90     679.90
#
#    GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 0                          0.23                             0.67
# 1                          3.45                             0.78
# 2                          2.34                             0.56
# 3                          9.76                             0.56
# 4                          1.23                             0.87
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 0                                      0.890000       0.56       0.450000
# 1                                      0.880000       0.67       0.753333
# 2                                      0.774615       0.67       0.753333
# 3                                      0.774615       0.67       0.753333
# 4                                      0.774615       0.56       0.450000
#
#    total_buy_price  total_sell_price  sum_of_transation_taxes/quantity  \
# 0           5800.0           18157.8                          2.800000
# 1          90000.0          181578.0                          6.533333
# 2          16822.8           27236.7                          5.097949
# 3          92156.0          181578.0                         12.517949
# 4          27057.0           20397.0                          3.884615
#
#    total_transcation_taxes
# 0                56.000000
# 1              1306.666667
# 2               152.938462
# 3              2503.589744
# 4               116.538462

# %%
dataset1['net']=dataset1['total_sell_price']-dataset1['total_buy_price']-dataset1['total_transcation_taxes']
dataset1.head()
# Out:
#    OPENPRICE  DAYHIGH  DAYLOW  BUYPRICE  SELLPRICE  \
# 0     230.00   359.67  345.56    290.00     907.89
# 1     240.00   764.70  564.46    450.00     907.89
# 2     140.66   890.67  654.67    560.76     907.89
# 3     253.66   890.67  657.57    460.78     907.89
# 4     140.66   890.67  675.57    901.90     679.90
#
#    GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# 0                          0.23                             0.67
# 1                          3.45                             0.78
# 2                          2.34                             0.56
# 3                          9.76                             0.56
# 4                          1.23                             0.87
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 0                                      0.890000       0.56       0.450000
# 1                                      0.880000       0.67       0.753333
# 2                                      0.774615       0.67       0.753333
# 3                                      0.774615       0.67       0.753333
# 4                                      0.774615       0.56       0.450000
#
#    total_buy_price  total_sell_price  sum_of_transation_taxes/quantity  \
# 0           5800.0           18157.8                          2.800000
# 1          90000.0          181578.0                          6.533333
# 2          16822.8           27236.7                          5.097949
# 3          92156.0          181578.0                         12.517949
# 4          27057.0           20397.0                          3.884615
#
#    total_transcation_taxes           net
# 0                56.000000  12301.800000
# 1              1306.666667  90271.333333
# 2               152.938462  10260.961538
# 3              2503.589744  86918.410256
# 4               116.538462  -6776.538462

# %%
def gain(value):
  if value < 0:
    return 'loss'
  if value > 0:
    return 'profit'
dataset1['gain']=dataset1['net'].map(gain)

# %%
dataset1.shape
# Out:
# (50, 16)

# %% [markdown]
# ## **FINALLY OBTAINED DATAFRAME**

# %%
finaldataset=pd.concat([dataset,dataset1],axis=1)
pd.set_option('display.max_columns',None)
finaldataset.head()
# Out:
#          DATE  SCRIPT_ID                  SECTOR EXCHANGE  QUANTITY  TYPE  \
# 0  12-02-2022  INE5A0001         oil corporation      NSE      20.0   buy
# 1  12-02-2022  INE5A0002         oil corporation      NSE     200.0  sell
# 2  12-02-2022  INE5A0003         oil corporation      BSE      30.0   buy
# 3  14-02-2022  INE5A0004  power grid corporation      NSE     200.0   buy
# 4  14-02-2022  INE5A0005                  metals      NSE      30.0   buy
#
#                                       BROKER_NAME     ORDERNO  \
# 0  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   100589001
# 1  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   011322675
# 2  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED   000765442
# 3  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED  0874544564
# 4  (UPSTOX) RKSV SECURITIES INDIA PRIVATE LIMITED  0774544224
#
#          TRADE_NAME PERSON_NAME       PAN_NO      UCC_NO  OPENPRICE  DAYHIGH  \
# 0        indian oil     chandra   APO5EE9078  2000155674     230.00   359.67
# 1              hpcl      suresh  APO5O6GGG5A  2345518900     240.00   764.70
# 2  bharat petroleum     sirisha  APO5OOH6345  0999670054     140.66   890.67
# 3             ntpc       harika  APO590OO7T8   676466894     253.66   890.67
# 4       vadanta ltd     saranya  APO5UY67001  6756545501     140.66   890.67
#
#    DAYLOW  BUYPRICE  SELLPRICE  GOVERNAMENT_SERVICE_TAX(GST)  \
# 0  345.56    290.00     907.89                          0.23
# 1  564.46    450.00     907.89                          3.45
# 2  654.67    560.76     907.89                          2.34
# 3  657.57    460.78     907.89                          9.76
# 4  675.57    901.90     679.90                          1.23
#
#    SECURITIES_TRANSCATION_TAX(STT)  \
# 0                             0.67
# 1                             0.78
# 2                             0.56
# 3                             0.56
# 4                             0.87
#
#    SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# 0                                      0.890000       0.56       0.450000
# 1                                      0.880000       0.67       0.753333
# 2                                      0.774615       0.67       0.753333
# 3                                      0.774615       0.67       0.753333
# 4                                      0.774615       0.56       0.450000
#
#    total_buy_price  total_sell_price  sum_of_transation_taxes/quantity  \
# 0           5800.0           18157.8                          2.800000
# 1          90000.0          181578.0                          6.533333
# 2          16822.8           27236.7                          5.097949
# 3          92156.0          181578.0                         12.517949
# 4          27057.0           20397.0                          3.884615
#
#    total_transcation_taxes           net    gain
# 0                56.000000  12301.800000  profit
# 1              1306.666667  90271.333333  profit
# 2               152.938462  10260.961538  profit
# 3              2503.589744  86918.410256  profit
# 4               116.538462  -6776.538462    loss

# %%
finaldataset.columns
# Out:
# Index(['DATE', 'SCRIPT_ID', 'SECTOR', 'EXCHANGE', 'QUANTITY', 'TYPE',
#        'BROKER_NAME', 'ORDERNO', 'TRADE_NAME', 'PERSON_NAME', 'PAN_NO',
#        'UCC_NO', 'OPENPRICE', 'DAYHIGH', 'DAYLOW', 'BUYPRICE', 'SELLPRICE',
#        'GOVERNAMENT_SERVICE_TAX(GST)', 'SECURITIES_TRANSCATION_TAX(STT)',
#        'SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)', 'STAMPDUTY',
#        'BROKERAGE_FEE', 'total_buy_price', 'total_sell_price',
#        'sum_of_transation_taxes/quantity', 'total_transcation_taxes', 'net',
#        'gain'],
#       dtype='object')

# %%
finaldataset.shape
# Out:
# (50, 28)

# %%
finaldataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 28 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   DATE                                          50 non-null     object
#  1   SCRIPT_ID                                     50 non-null     object
#  2   SECTOR                                        50 non-null     object
#  3   EXCHANGE                                      50 non-null     object
#  4   QUANTITY                                      50 non-null     float64
#  5   TYPE                                          50 non-null     object
#  6   BROKER_NAME                                   50 non-null     object
#  7   ORDERNO                                       50 non-null     object
#  8   TRADE_NAME                                    50 non-null     object
#  9   PERSON_NAME                                   50 non-null     object
#  10  PAN_NO                                        50 non-null     object
#  11  UCC_NO                                        50 non-null     object
#  12  OPENPRICE                                     50 non-null     float64
#  13  DAYHIGH                                       50 non-null     float64
#  14  DAYLOW                                        50 non-null     float64
#  15  BUYPRICE                                      50 non-null     float64
#  16  SELLPRICE                                     50 non-null     float64
#  17  GOVERNAMENT_SERVICE_TAX(GST)                  50 non-null     float64
#  18  SECURITIES_TRANSCATION_TAX(STT)               50 non-null     float64
#  19  SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  50 non-null     float64
#  20  STAMPDUTY                                     50 non-null     float64
#  21  BROKERAGE_FEE                                 50 non-null     float64
#  22  total_buy_price                               50 non-null     float64
#  23  total_sell_price                              50 non-null     float64
#  24  sum_of_transation_taxes/quantity              50 non-null     float64
#  25  total_transcation_taxes                       50 non-null     float64
#  26  net                                           50 non-null     float64
#  27  gain                                          50 non-null     object
# dtypes: float64(16), object(12)
# memory usage: 11.1+ KB

# %%
finaldataset.ndim #dimension of finaldataset
# Out:
# 2

# %%
finaldataset.describe()
# Out:
#          QUANTITY   OPENPRICE     DAYHIGH      DAYLOW   BUYPRICE   SELLPRICE  \
# count   50.000000   50.000000   50.000000   50.000000   50.00000   50.000000
# mean   111.620000  317.161800  758.171400  352.658800  781.21460  825.524400
# std     64.052558  179.194788  149.239147  146.667306  170.22331  102.544243
# min     20.000000  140.660000  345.560000  234.450000  290.00000  643.670000
# 25%     67.000000  141.917500  675.560000  234.450000  679.15500  764.927500
# 50%     90.000000  254.665000  786.170000  342.610000  907.28000  901.730000
# 75%    200.000000  425.685000  890.670000  455.750000  907.78000  907.890000
# max    200.000000  678.780000  890.670000  675.570000  907.78000  907.890000
#
#        GOVERNAMENT_SERVICE_TAX(GST)  SECURITIES_TRANSCATION_TAX(STT)  \
# count                     50.000000                        50.000000
# mean                       6.276400                         0.695000
# std                        3.026409                         0.125523
# min                        0.230000                         0.560000
# 25%                        3.810000                         0.560000
# 50%                        6.560000                         0.715000
# 75%                        9.760000                         0.780000
# max                        9.760000                         0.990000
#
#        SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  STAMPDUTY  BROKERAGE_FEE  \
# count                                     50.000000  50.000000      50.000000
# mean                                       0.774615   0.597200       0.753333
# std                                        0.066738   0.105773       0.335129
# min                                        0.560000   0.480000       0.230000
# 25%                                        0.774615   0.480000       0.560000
# 50%                                        0.774615   0.565000       0.730000
# 75%                                        0.780000   0.670000       0.758333
# max                                        0.890000   0.780000       1.640000
#
#        total_buy_price  total_sell_price  sum_of_transation_taxes/quantity  \
# count        50.000000         50.000000                         50.000000
# mean      86345.596000      93905.794200                          9.096549
# std       52092.339896      58580.518699                          3.154125
# min        5800.000000      13151.400000                          2.800000
# 25%       50726.420000      51556.520000                          6.690000
# 50%       68991.280000      69135.420000                          9.279615
# 75%      109939.937500     166805.000000                         12.276154
# max      181556.000000     181578.000000                         13.414615
#
#        total_transcation_taxes           net
# count                50.000000     50.000000
# mean               1070.127533   6490.070667
# std                 765.768497  26827.727791
# min                  56.000000 -30710.000000
# 25%                 519.300192  -3428.178205
# 50%                 850.475641   -511.684615
# 75%                1589.192308   9846.143654
# max                2567.589744  90271.333333

# %%
Df3=finaldataset.filter(['QUANTITY','OPENPRICE','DAYHIGH','DAYLOW	BUYPRICE','SELLPRICE','GOVERNAMENT_SERVICE_TAX(GST)','SECURITIES_TRANSCATION_TAX(STT)','SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)','	STAMPDUTY','BROKERAGE_FEE','total_buy_price','total_sell_price','sum_of_transation_taxes/quantity','total_transcation_taxes','net'])
Df3.corr()#corelation
# Out:
#                                               QUANTITY  OPENPRICE   DAYHIGH  \
# QUANTITY                                      1.000000   0.210666 -0.014053
# OPENPRICE                                     0.210666   1.000000  0.023488
# DAYHIGH                                      -0.014053   0.023488  1.000000
# SELLPRICE                                     0.273544   0.015244 -0.096434
# GOVERNAMENT_SERVICE_TAX(GST)                  0.266491   0.379778  0.115666
# SECURITIES_TRANSCATION_TAX(STT)               0.175942   0.297951 -0.164210
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI) -0.172004  -0.168549  0.019445
# BROKERAGE_FEE                                 0.117751   0.047044 -0.077654
# total_buy_price                               0.904987   0.193211 -0.053324
# total_sell_price                              0.985996   0.217179 -0.021075
# sum_of_transation_taxes/quantity              0.276635   0.377400  0.093668
# total_transcation_taxes                       0.879776   0.343543  0.016520
# net                                           0.370645   0.089258  0.057050
#
#                                               SELLPRICE  \
# QUANTITY                                       0.273544
# OPENPRICE                                      0.015244
# DAYHIGH                                       -0.096434
# SELLPRICE                                      1.000000
# GOVERNAMENT_SERVICE_TAX(GST)                  -0.083685
# SECURITIES_TRANSCATION_TAX(STT)               -0.066409
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)   0.091929
# BROKERAGE_FEE                                 -0.219765
# total_buy_price                                0.246432
# total_sell_price                               0.411076
# sum_of_transation_taxes/quantity              -0.096097
# total_transcation_taxes                        0.215819
# net                                            0.412951
#
#                                               GOVERNAMENT_SERVICE_TAX(GST)  \
# QUANTITY                                                          0.266491
# OPENPRICE                                                         0.379778
# DAYHIGH                                                           0.115666
# SELLPRICE                                                        -0.083685
# GOVERNAMENT_SERVICE_TAX(GST)                                      1.000000
# SECURITIES_TRANSCATION_TAX(STT)                                  -0.031046
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                     -0.375661
# BROKERAGE_FEE                                                     0.355822
# total_buy_price                                                   0.204584
# total_sell_price                                                  0.246768
# sum_of_transation_taxes/quantity                                  0.994498
# total_transcation_taxes                                           0.608712
# net                                                               0.124216
#
#                                               SECURITIES_TRANSCATION_TAX(STT)  \
# QUANTITY                                                             0.175942
# OPENPRICE                                                            0.297951
# DAYHIGH                                                             -0.164210
# SELLPRICE                                                           -0.066409
# GOVERNAMENT_SERVICE_TAX(GST)                                        -0.031046
# SECURITIES_TRANSCATION_TAX(STT)                                      1.000000
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                        -0.135937
# BROKERAGE_FEE                                                       -0.162878
# total_buy_price                                                      0.244814
# total_sell_price                                                     0.154413
# sum_of_transation_taxes/quantity                                    -0.003783
# total_transcation_taxes                                              0.140151
# net                                                                 -0.142191
#
#                                               SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  \
# QUANTITY                                                                         -0.172004
# OPENPRICE                                                                        -0.168549
# DAYHIGH                                                                           0.019445
# SELLPRICE                                                                         0.091929
# GOVERNAMENT_SERVICE_TAX(GST)                                                     -0.375661
# SECURITIES_TRANSCATION_TAX(STT)                                                  -0.135937
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                                      1.000000
# BROKERAGE_FEE                                                                    -0.142270
# total_buy_price                                                                  -0.171683
# total_sell_price                                                                 -0.132993
# sum_of_transation_taxes/quantity                                                 -0.358449
# total_transcation_taxes                                                          -0.302509
# net                                                                               0.051597
#
#                                               BROKERAGE_FEE  total_buy_price  \
# QUANTITY                                           0.117751         0.904987
# OPENPRICE                                          0.047044         0.193211
# DAYHIGH                                           -0.077654        -0.053324
# SELLPRICE                                         -0.219765         0.246432
# GOVERNAMENT_SERVICE_TAX(GST)                       0.355822         0.204584
# SECURITIES_TRANSCATION_TAX(STT)                   -0.162878         0.244814
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)      -0.142270        -0.171683
# BROKERAGE_FEE                                      1.000000         0.116952
# total_buy_price                                    0.116952         1.000000
# total_sell_price                                   0.059954         0.886386
# sum_of_transation_taxes/quantity                   0.435500         0.221518
# total_transcation_taxes                            0.263123         0.764320
# net                                               -0.103686        -0.028056
#
#                                               total_sell_price  \
# QUANTITY                                              0.985996
# OPENPRICE                                             0.217179
# DAYHIGH                                              -0.021075
# SELLPRICE                                             0.411076
# GOVERNAMENT_SERVICE_TAX(GST)                          0.246768
# SECURITIES_TRANSCATION_TAX(STT)                       0.154413
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)         -0.132993
# BROKERAGE_FEE                                         0.059954
# total_buy_price                                       0.886386
# total_sell_price                                      1.000000
# sum_of_transation_taxes/quantity                      0.252967
# total_transcation_taxes                               0.862058
# net                                                   0.437848
#
#                                               sum_of_transation_taxes/quantity  \
# QUANTITY                                                              0.276635
# OPENPRICE                                                             0.377400
# DAYHIGH                                                               0.093668
# SELLPRICE                                                            -0.096097
# GOVERNAMENT_SERVICE_TAX(GST)                                          0.994498
# SECURITIES_TRANSCATION_TAX(STT)                                      -0.003783
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                         -0.358449
# BROKERAGE_FEE                                                         0.435500
# total_buy_price                                                       0.221518
# total_sell_price                                                      0.252967
# sum_of_transation_taxes/quantity                                      1.000000
# total_transcation_taxes                                               0.615872
# net                                                                   0.104665
#
#                                               total_transcation_taxes  \
# QUANTITY                                                     0.879776
# OPENPRICE                                                    0.343543
# DAYHIGH                                                      0.016520
# SELLPRICE                                                    0.215819
# GOVERNAMENT_SERVICE_TAX(GST)                                 0.608712
# SECURITIES_TRANSCATION_TAX(STT)                              0.140151
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                -0.302509
# BROKERAGE_FEE                                                0.263123
# total_buy_price                                              0.764320
# total_sell_price                                             0.862058
# sum_of_transation_taxes/quantity                             0.615872
# total_transcation_taxes                                      1.000000
# net                                                          0.369721
#
#                                                    net
# QUANTITY                                      0.370645
# OPENPRICE                                     0.089258
# DAYHIGH                                       0.057050
# SELLPRICE                                     0.412951
# GOVERNAMENT_SERVICE_TAX(GST)                  0.124216
# SECURITIES_TRANSCATION_TAX(STT)              -0.142191
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  0.051597
# BROKERAGE_FEE                                -0.103686
# total_buy_price                              -0.028056
# total_sell_price                              0.437848
# sum_of_transation_taxes/quantity              0.104665
# total_transcation_taxes                       0.369721
# net                                           1.000000

# %%
Df3.cov()#covariation
# Out:
#                                                   QUANTITY     OPENPRICE  \
# QUANTITY                                      4.102730e+03  2.418002e+03
# OPENPRICE                                     2.418002e+03  3.211077e+04
# DAYHIGH                                      -1.343380e+02  6.281292e+02
# SELLPRICE                                     1.796695e+03  2.801079e+02
# GOVERNAMENT_SERVICE_TAX(GST)                  5.165901e+01  2.059601e+02
# SECURITIES_TRANSCATION_TAX(STT)               1.414592e+00  6.701848e+00
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI) -7.352747e-01 -2.015703e+00
# BROKERAGE_FEE                                 2.527619e+00  2.825176e+00
# total_buy_price                               3.019621e+06  1.803564e+06
# total_sell_price                              3.699684e+06  2.279802e+06
# sum_of_transation_taxes/quantity              5.588854e+01  2.133076e+02
# total_transcation_taxes                       4.315250e+04  4.714150e+04
# net                                           6.369103e+05  4.290965e+05
#
#                                                     DAYHIGH     SELLPRICE  \
# QUANTITY                                        -134.338029  1.796695e+03
# OPENPRICE                                        628.129193  2.801079e+02
# DAYHIGH                                        22272.322988 -1.475791e+03
# SELLPRICE                                      -1475.790733  1.051532e+04
# GOVERNAMENT_SERVICE_TAX(GST)                      52.241621 -2.597102e+01
# SECURITIES_TRANSCATION_TAX(STT)                   -3.076144 -8.548020e-01
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)       0.193669  6.291297e-01
# BROKERAGE_FEE                                     -3.883825 -7.552348e+00
# total_buy_price                              -414552.628686  1.316384e+06
# total_sell_price                             -184249.983153  2.469370e+06
# sum_of_transation_taxes/quantity                  44.091401 -3.108136e+01
# total_transcation_taxes                         1887.898294  1.694719e+04
# net                                           228414.747239  1.136039e+06
#
#                                               GOVERNAMENT_SERVICE_TAX(GST)  \
# QUANTITY                                                         51.659012
# OPENPRICE                                                       205.960107
# DAYHIGH                                                          52.241621
# SELLPRICE                                                       -25.971016
# GOVERNAMENT_SERVICE_TAX(GST)                                      9.159154
# SECURITIES_TRANSCATION_TAX(STT)                                  -0.011794
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                     -0.075875
# BROKERAGE_FEE                                                     0.360888
# total_buy_price                                               32253.154744
# total_sell_price                                              43749.171485
# sum_of_transation_taxes/quantity                                  9.493152
# total_transcation_taxes                                        1410.706958
# net                                                           10085.309782
#
#                                               SECURITIES_TRANSCATION_TAX(STT)  \
# QUANTITY                                                             1.414592
# OPENPRICE                                                            6.701848
# DAYHIGH                                                             -3.076144
# SELLPRICE                                                           -0.854802
# GOVERNAMENT_SERVICE_TAX(GST)                                        -0.011794
# SECURITIES_TRANSCATION_TAX(STT)                                      0.015756
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                        -0.001139
# BROKERAGE_FEE                                                       -0.006852
# total_buy_price                                                   1600.792173
# total_sell_price                                                  1135.435932
# sum_of_transation_taxes/quantity                                    -0.001498
# total_transcation_taxes                                             13.471535
# net                                                               -478.827777
#
#                                               SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  \
# QUANTITY                                                                         -0.735275
# OPENPRICE                                                                        -2.015703
# DAYHIGH                                                                           0.193669
# SELLPRICE                                                                         0.629130
# GOVERNAMENT_SERVICE_TAX(GST)                                                     -0.075875
# SECURITIES_TRANSCATION_TAX(STT)                                                  -0.001139
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                                      0.004454
# BROKERAGE_FEE                                                                    -0.003182
# total_buy_price                                                                -596.866907
# total_sell_price                                                               -519.945951
# sum_of_transation_taxes/quantity                                                 -0.075454
# total_transcation_taxes                                                         -15.460065
# net                                                                              92.381021
#
#                                               BROKERAGE_FEE  total_buy_price  \
# QUANTITY                                           2.527619     3.019621e+06
# OPENPRICE                                          2.825176     1.803564e+06
# DAYHIGH                                           -3.883825    -4.145526e+05
# SELLPRICE                                         -7.552348     1.316384e+06
# GOVERNAMENT_SERVICE_TAX(GST)                       0.360888     3.225315e+04
# SECURITIES_TRANSCATION_TAX(STT)                   -0.006852     1.600792e+03
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)      -0.003182    -5.968669e+02
# BROKERAGE_FEE                                      0.112312     2.041713e+03
# total_buy_price                                 2041.712870     2.713612e+09
# total_sell_price                                1177.023887     2.704892e+09
# sum_of_transation_taxes/quantity                   0.460340     3.639673e+04
# total_transcation_taxes                           67.525595     3.048925e+07
# net                                             -932.214578    -3.920878e+07
#
#                                               total_sell_price  \
# QUANTITY                                          3.699684e+06
# OPENPRICE                                         2.279802e+06
# DAYHIGH                                          -1.842500e+05
# SELLPRICE                                         2.469370e+06
# GOVERNAMENT_SERVICE_TAX(GST)                      4.374917e+04
# SECURITIES_TRANSCATION_TAX(STT)                   1.135436e+03
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)     -5.199460e+02
# BROKERAGE_FEE                                     1.177024e+03
# total_buy_price                                   2.704892e+09
# total_sell_price                                  3.431677e+09
# sum_of_transation_taxes/quantity                  4.674083e+04
# total_transcation_taxes                           3.867114e+07
# net                                               6.881137e+08
#
#                                               sum_of_transation_taxes/quantity  \
# QUANTITY                                                             55.888536
# OPENPRICE                                                           213.307625
# DAYHIGH                                                              44.091401
# SELLPRICE                                                           -31.081363
# GOVERNAMENT_SERVICE_TAX(GST)                                          9.493152
# SECURITIES_TRANSCATION_TAX(STT)                                      -0.001498
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)                         -0.075454
# BROKERAGE_FEE                                                         0.460340
# total_buy_price                                                   36396.731476
# total_sell_price                                                  46740.825454
# sum_of_transation_taxes/quantity                                      9.948502
# total_transcation_taxes                                            1487.532648
# net                                                                8856.561331
#
#                                               total_transcation_taxes  \
# QUANTITY                                                 4.315250e+04
# OPENPRICE                                                4.714150e+04
# DAYHIGH                                                  1.887898e+03
# SELLPRICE                                                1.694719e+04
# GOVERNAMENT_SERVICE_TAX(GST)                             1.410707e+03
# SECURITIES_TRANSCATION_TAX(STT)                          1.347154e+01
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)            -1.546007e+01
# BROKERAGE_FEE                                            6.752559e+01
# total_buy_price                                          3.048925e+07
# total_sell_price                                         3.867114e+07
# sum_of_transation_taxes/quantity                         1.487533e+03
# total_transcation_taxes                                  5.864014e+05
# net                                                      7.595485e+06
#
#                                                        net
# QUANTITY                                      6.369103e+05
# OPENPRICE                                     4.290965e+05
# DAYHIGH                                       2.284147e+05
# SELLPRICE                                     1.136039e+06
# GOVERNAMENT_SERVICE_TAX(GST)                  1.008531e+04
# SECURITIES_TRANSCATION_TAX(STT)              -4.788278e+02
# SECURITIES_AND_EXCHANGE_BOARD_OF_INDIA(SEBI)  9.238102e+01
# BROKERAGE_FEE                                -9.322146e+02
# total_buy_price                              -3.920878e+07
# total_sell_price                              6.881137e+08
# sum_of_transation_taxes/quantity              8.856561e+03
# total_transcation_taxes                       7.595485e+06
# net                                           7.197270e+08

# %% [markdown]
# # **data visualization**

# %% [markdown]
# ### **Line graph**

# %%
df5=finaldataset['OPENPRICE'].iloc[20:31]
df6=finaldataset['DAYHIGH'].iloc[20:31]
df7=finaldataset['DAYLOW'].iloc[20:31]
DF1=finaldataset['DATE'].iloc[20:31]

# %% [markdown]
# line graph values

# %%
pd.concat([DF1,df5,df6,df7],axis=1)
# Out:
#           DATE  OPENPRICE  DAYHIGH  DAYLOW
# 20  16-03-2022     140.66   890.67  234.45
# 21  17-03-2022     235.77   890.67  234.45
# 22  18-03-2022     238.99   567.57  345.56
# 23  18-03-2022     255.67   679.68  456.48
# 24  19-03-2022     140.66   675.67  342.77
# 25  20-03-2022     258.96   890.67  345.67
# 26  22-03-2022     234.56   890.67  675.56
# 27  23-03-2022     140.66   890.67  463.56
# 28  24-03-2022     534.78   675.55  564.44
# 29  25-03-2022     345.89   890.67  345.67
# 30  26-03-2022     140.66   675.56  234.45

# %%
plt.plot(DF1,df5,marker='d',color='red',label='OPENPRICE')
plt.plot(DF1,df6,marker='+',color='green',label='DAYHIGH')
plt.plot(DF1,df7,marker='*',color='blue',label='DAYLOW')
plt.xticks(color='slateblue')
plt.tick_params(axis='x',labelrotation=90)
plt.xlabel('trade days',fontsize=20,labelpad=20)
plt.ylabel('price',fontsize=20,labelpad=20)
plt.title('stock predicted',pad=20)
plt.grid(alpha=0.5)
plt.legend(frameon=True,framealpha=0.8,edgecolor='aqua',ncol=1,fontsize='small',labelspacing=1)
plt.show()

# %% [markdown]
# ### **bar graph**

# %%
dfx=finaldataset['total_buy_price'].iloc[0:10]
dfy=finaldataset['PERSON_NAME'].iloc[0:10]
df3=finaldataset['total_sell_price'].iloc[0:10]
df4=finaldataset['net'].iloc[0:10]
df8=finaldataset['gain'].iloc[0:10]

# %% [markdown]
# bar graph values

# %%
pd.concat([dfy,dfx,df3,df4,df8],axis=1)
# Out:
#   PERSON_NAME  total_buy_price  total_sell_price           net    gain
# 0     chandra          5800.00          18157.80  12301.800000  profit
# 1      suresh         90000.00         181578.00  90271.333333  profit
# 2     sirisha         16822.80          27236.70  10260.961538  profit
# 3      harika         92156.00         181578.00  86918.410256  profit
# 4     saranya         27057.00          20397.00  -6776.538462    loss
# 5     promodh        181556.00         171356.00 -10980.923077    loss
# 6        mary         36311.20          36315.60   -153.600000    loss
# 7       amala         32680.08          32684.04   -133.920000    loss
# 8       sindu         60821.26          52923.30  -8176.680000    loss
# 9       ramba         45432.00          62862.40  16857.600000  profit

# %%
w=0.1985
x=dfy
bar1=np.arange(len(dfy))
bar2=[i+w for i in bar1]
bar3=[i+w for i in bar2]
plt.bar(bar1,dfx,width=w,label='total_buy_price')
plt.bar(bar2,df3,width=w,label='total_sell_price')
plt.bar(bar3,df4,width=w,label='net')
plt.xticks(bar1+w,x,size=10,rotation=90)
plt.xlabel('traders',fontsize=20,color='red',alpha=0.6)
plt.ylabel('stocks predicted',fontsize=20,color='red',alpha=0.6)
plt.title('traders net worth',pad=10)
plt.legend(edgecolor='black')
plt.show()

# %% [markdown]
# ### **Heat map for corelation**

# %%
sns.heatmap(Df3.corr())
plt.plot()
# Out:
# []
